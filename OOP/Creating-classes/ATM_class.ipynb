# %%
class Atm:
  # constructor (special function)
    def __init__(self):
        self.pin = ""
        self.balance = 10000
        self.menu()
    
    def menu(self):
        while True:
            user_input = input("""
            Hi how can I help you?
            1. Press 1 to create pin
            2. Press 2 to change pin
            3. Press 3 to check balance
            4. Press 4 to withdraw
            5. Press 5 to exit
            6. Press 6 to deposite
            """)

            if user_input == '1':
                self.create_pin()
            elif user_input == '2':
                self.change_pin()
            elif user_input == '3':
                self.check_balance()
            elif user_input == '4':
                self.withdraw()
            elif user_input == '5':
                print("Thank you for using ATM")
                break
            else:
                print("Invalid choice")
    
    # create PIN
    def create_pin(self):
        self.pin = input("Enter your pin")
        print("PIN created successfully")

    # change PIN
    def change_pin(self):
        old_pin = input("Enter old pin")
        if old_pin == self.pin:
            self.pin = input("Enter new pin")
            print("PIN changed successfully")
            self.menu()
        else:
            print("you entered wrong pin")
    
   
    # check balance   
    def check_balance(self):
        user_pin = input("Enter ur pin")
        if user_pin == self.pin:
            print("Your balance is:", self.balance)
        else:
            print("Incorrect Pin")
    
    
    # withdraw money
    def withdraw(self):
        user_pin = input("Enter ur pin")
        if user_pin == self.pin:
            amount = print("Enter your amount to withdraw")
            if amount <= self.balance:
                print("Take your money")
                slef.balance = self.balance - amount
            else:
                print("Insaficiant balance")
        else:
            print("Incorrect PIN")
            self.menu()
            
obj = Atm()
