# %% [markdown]
# ### Exercise : Build a class Employee with multiple constructors that can initialize an employee object in different ways.

# %%
class Employee:
    
    def __init__(self, name, id=None)
