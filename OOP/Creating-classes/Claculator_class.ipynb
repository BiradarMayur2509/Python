# %% [markdown]
# ## Exercise : Develop a class Calculator with methods to add and subtract two numbers.

# %%
class Calculator:
    
    def __init__(self):
        pass 
    
    def add(self, a, b):
        return a + b
    
    def subtract(self, a, b):
        return a - b
    
# testing the calculator

calc = Calculator() # object creation

print("Sum:", calc.add(5, 3))
print("Difference:", calc.subtract(5, 3))
# Out:
# Sum: 8
# Difference: 2
