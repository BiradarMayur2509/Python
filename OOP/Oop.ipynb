# %% [markdown]
# # OOP Exercise 1: Create a Class with instance attributes
# Write a Python program to create a Vehicle class with max_speed and mileage instance attributes.
#
# #### Solution:

# %%
class Vehicle:
    
    def __init__(self, max_speed, milage):
        self.max_speed = max_speed
        self.milage = milage
        

modelX = Vehicle(140, 18)

print(modelX.max_speed, modelX.milage)
# Out:
# 140 18

# %% [markdown]
# # OOP Exercise 2: Create a Vehicle class without any variables and methods
#
# #### Solution

# %%
class Vehicle:
    pass

# %% [markdown]
# # OOP Exercise 3: Create a child class Bus that will inherit all of the variables and methods of the Vehicle class
# Given:
#
# class Vehicle:
#
#     def __init__(self, name, max_speed, mileage):
#         self.name = name
#         self.max_speed = max_speed
#         self.mileage = mileage
#
# Create a Bus object that will inherit all of the variables and methods of the parent Vehicle class and display it.
#
# Expected Output:
#
#     Vehicle Name: School Volvo Speed: 180 Mileage: 12
#
# ### Solution

# %%
class Vehicle:
    
    def __init__(self, name, max_speed, milage):
        self.name = name
        self.max_speed = max_speed
        self.milage = milage
        
class Bus(Vehicle):
    pass

School_bus = Bus("School Bus" , 80, 12)
print(f"Vehichle Type name : {School_bus.name} Speed: {School_bus.max_speed} milage: {School_bus.milage}")
# Out:
# Vehichle Type name : School Bus Speed: 80 milage: 12
